# %% [markdown]
# <a href="https://colab.research.google.com/github/analyticsariel/market-research-data/blob/main/API_US_Housing_Market_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # US Housing Market Data
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1q1PRWd1hTFQFqu2pY_e6vxMmEVh3f2AS?usp=sharing)
#
#
# ## Overview
# | Detail Tag            | Information                                                                                        |
# |-----------------------|----------------------------------------------------------------------------------------------------|
# | Originally Created By | Ariel Herrera arielherrera@analyticsariel.com |
# | External References   | API |
# | Input Datasets        | Source name |
# | Output Datasets       | Source name |
# | Input Data Source     | Pandas DataFrame |
# | Output Data Source    | Pandas DataFrame |
#
# ## History
# | Date         | Developed By  | Reason                                                |
# |--------------|---------------|-------------------------------------------------------|
# | 1st Sep 2022 | Ariel Herrera | Create notebook. |
#
# ## Getting Started
# 1. Copy this notebook -> File -> Save a Copy in Drive
# 2. Directions
#
# ## Useful Resources
# - [Google Colab Cheat Sheet](https://towardsdatascience.com/cheat-sheet-for-google-colab-63853778c093)

# %% [markdown]
# ## <font color="blue">Install Packages</font>

# %% [markdown]
# ## <font color="blue">Imports</font>

# %%
from google.colab import drive, files, output # specific to Google Colab
import requests
import time

# data wrangling
import pandas as pd

# visualization
import plotly.express as px

# settings
pd.set_option('display.max_columns', None) # show all columns

# %% [markdown]
# ## <font color="blue">Functions</font>

# %% [markdown]
# ## <font color="blue">Locals & Constants</font>

# %%
########################################################################
# OPTIONAL                                                             #
# 1) Create a file called 'api_keys.csv' to store your Rapid API key   #
# 2) Read in the file                                                  #
# 3) Set the Rapid API key to the rapid_api_key variable               #
########################################################################

# mount drive
drive.mount('/content/drive', force_remount=False)

# data location
file_dir = '/content/drive/My Drive/Colab Data/input/' # optional
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# read in api key file
df_api_keys = pd.read_csv(file_dir + 'api_keys.csv')

# get keys
rapid_api_key = df_api_keys.loc[df_api_keys['API'] =='rapid']['KEY'].iloc[0] # replace this with your own key

# %% [markdown]
# ## <font color="blue">Data</font>

# %% [markdown]
# ### <font color="green">Section #1 - API Requests</font> 💻
# This section will cover how to make API requests to the [US Housing Market Data API](https://bit.ly/3AHH7sY). It demonstrates how to modify your search based on different parameters.

# %% [markdown]
# #### <font color="purple">1. National Region</font> 🏘

# %% [markdown]
# ##### <font color="orange">Standard Query</font> ✨

# %%
url = "https://us-housing-market-data.p.rapidapi.com/getNational"

headers = {
	"X-RapidAPI-Key": rapid_api_key,
	"X-RapidAPI-Host": "us-housing-market-data.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers)

print(response.text)
# Out:
# {"0":{"period_begin":"2021-05-01","period_end":"2021-05-31","period_duration":30,"region_type":"national","region_type_id":11,"table_id":1400,"is_seasonally_adjusted":"f","region":" National","city":"National","state":"U.S.","state_code":"US","property_type":"Condo\/Co-op","property_type_id":3,"median_sale_price":301300.0,"median_sale_price_mom":-0.0014343403,"median_sale_price_yoy":0.1993395025,"median_list_price":310943.0,"median_list_price_mom":0.0000373406,"median_list_price_yoy":0.1010641588,"median_ppsf":264.0,"median_ppsf_mom":-0.0021961071,"median_ppsf_yoy":0.2544111844,"median_list_ppsf":273.0,"median_list_ppsf_mom":-0.0025393944,"median_list_ppsf_yoy":0.1303618152,"homes_sold":78553.0,"homes_sold_mom":-0.0475370046,"homes_sold_yoy":1.1197645603,"pending_sales":74952.0,"pending_sales_mom":-0.0066427043,"pending_sales_yoy":0.7191823539,"new_listings":86096.0,"new_listings_mom":-0.053764934,"new_listings_yoy":0.2516715764,"inventory":128559.0,"inventory_mom":-0.0149912311,"inventory_yoy":-0.2581433282,"months_of_supply":1.6365826934,"months_of_supply_mom":0.0540744928,"months_of_supply_yoy":-3.0397518674,"median_dom":25.0,"median_dom_mom":-4.0,"median_dom_yoy":-17.0,"avg_sale_to_list":1.0031148577,"avg_sale_to_list_mom":0.0054588257,"avg_sale_to_list_yoy":0.0255306427,"sold_above_list":0.3875868531,"sold_above_list_mom":0.042187284,"sold_above_list_yoy":0.2056949424,"price_drops":0.0802048819,"price_drops_mom":0.0023107702,"price_drops_yoy":-0.0288065879,"off_market_in_two_weeks":0.4983259171,"off_market_in_two_weeks_mom":0.0104932378,"off_market_in_two_weeks_yoy":0.1155990166,"parent_metro_region":null,"parent_metro_region_metro_code":null,"last_updated":"2022-08-14 14:47:34"},"1":{"period_begin":"2012-07-01","period_end":"2012-07-31","period_duration":30,"region_type":"national","region_type_id":11,"table_id":1400,"is_seasonally_adjusted":"f","region":" National","city":"National","state":"U.S.","state_code":"US","property_type":"Condo\/Co-op","property_type_id":3,"median_sale_price":156724.0,"median_sale_price_mom":-0.0373084783,"median_sale_price_yoy":0.0567023057,"median_list_price":160842.0,"median_list_price_mom":-0.0156893179,"median_list_price_yoy":0.019390475,"median_ppsf":133.0,"median_ppsf_mom":-0.0207100013,"median_ppsf_yoy":0.0458507678,"median_list_ppsf":135.0,"median_list_ppsf_mom":-0.0236921208,"median_list_ppsf_yoy":0.007986223,"homes_sold":52275.0,"homes_sold_mom":-0.0859087388,"homes_sold_yoy":0.1854997838,"pending_sales":36131.0,"pending_sales_mom":-0.0299075959,"pending_sales_yoy":0.2820904251,"new_listings":61937.0,"new_listings_mom":-0.0484431653,"new_listings_yoy":0.0525941347,"inventory":247999.0,"inventory_mom":-0.0238230372,"inventory_yoy":-0.2173452227,"months_of_supply":4.7441013015,"months_of_supply_mom":0.3017289578,"months_of_supply_yoy":-2.4418652702,"median_dom":73.0,"median_dom_mom":-2.0,"median_dom_yoy":-28.0,"avg_sale_to_list":0.965701476,"avg_sale_to_list_mom":0.0014094285,"avg_sale_to_list_yoy":0.0116617507,"sold_above_list":0.1856582308,"sold_above_list_mom":0.0056196344,"sold_above_list_yoy":0.0387326983,"price_drops":0.0617622797,"price_drops_mom":-0.0004185661,"price_drops_yoy":-0.0194924025,"off_market_in_two_weeks":0.2847468597,"off_market_in_two_weeks_mom":-0.0018280588,"off_market_in_two_weeks_yoy":0.0672768455,"parent_metro_region":null,"parent_metro_region_metro_code":null,"last_updated":"2022-08-14 14:47:34"},"2":{"period_begin":"2016-12-01","period_end":"2016-12-31","period_duration":30,"region_type":"national","region_type_id":11,"table_id":1400,"is_seasonally_adjusted":"f","region":" National","city":"National","state":"U.S.","state_code":"US","property_type":"Condo\/Co-op","property_type_id":3,"median_sale_price":224061.0,"median_sale_price_mom":-0.0427260801,"median_sale_price_yoy":0.0833614178,"median_list_price":226118.0,"median_list_price_mom":-0.0441273878,"median_list_price_yoy":0.1022777133,"median_ppsf":189.0,"median_ppsf_mom":-0.0431318749,"median_ppsf_yoy" ...

# %%
response.json()['0']
# Out:
# {'period_begin': '2021-05-01',
#  'period_end': '2021-05-31',
#  'period_duration': 30,
#  'region_type': 'national',
#  'region_type_id': 11,
#  'table_id': 1400,
#  'is_seasonally_adjusted': 'f',
#  'region': ' National',
#  'city': 'National',
#  'state': 'U.S.',
#  'state_code': 'US',
#  'property_type': 'Condo/Co-op',
#  'property_type_id': 3,
#  'median_sale_price': 301300.0,
#  'median_sale_price_mom': -0.0014343403,
#  'median_sale_price_yoy': 0.1993395025,
#  'median_list_price': 310943.0,
#  'median_list_price_mom': 3.73406e-05,
#  'median_list_price_yoy': 0.1010641588,
#  'median_ppsf': 264.0,
#  'median_ppsf_mom': -0.0021961071,
#  'median_ppsf_yoy': 0.2544111844,
#  'median_list_ppsf': 273.0,
#  'median_list_ppsf_mom': -0.0025393944,
#  'median_list_ppsf_yoy': 0.1303618152,
#  'homes_sold': 78553.0,
#  'homes_sold_mom': -0.0475370046,
#  'homes_sold_yoy': 1.1197645603,
#  'pending_sales': 74952.0,
#  'pending_sales_mom': -0.0066427043,
#  'pending_sales_yoy': 0.7191823539,
#  'new_listings': 86096.0,
#  'new_listings_mom': -0.053764934,
#  'new_listings_yoy': 0.2516715764,
#  'inventory': 128559.0,
#  'inventory_mom': -0.0149912311,
#  'inventory_yoy': -0.2581433282,
#  'months_of_supply': 1.6365826934,
#  'months_of_supply_mom': 0.0540744928,
#  'months_of_supply_yoy': -3.0397518674,
#  'median_dom': 25.0,
#  'median_dom_mom': -4.0,
#  'median_dom_yoy': -17.0,
#  'avg_sale_to_list': 1.0031148577,
#  'avg_sale_to_list_mom': 0.0054588257,
#  'avg_sale_to_list_yoy': 0.0255306427,
#  'sold_above_list': 0.3875868531,
#  'sold_above_list_mom': 0.042187284,
#  'sold_above_list_yoy': 0.2056949424,
#  'price_drops': 0.0802048819,
#  'price_drops_mom': 0.0023107702,
#  'price_drops_yoy': -0.0288065879,
#  'off_market_in_two_weeks': 0.4983259171,
#  'off_market_in_two_weeks_mom': 0.0104932378,
#  'off_market_in_two_weeks_yoy': 0.1155990166,
#  'parent_metro_region': None,
#  'parent_metro_region_metro_code': None,
#  'last_updated': '2022-08-14 14:47:34'}

# %%
df_national = pd.DataFrame.from_dict(response.json(), orient='index')
print('Num of rows: {}'.format(len(df_national)))
print('Num of columns: {}'.format(len(df_national.columns)))
year_list = df_national.apply(lambda x: x['period_begin'].split('-')[0], axis=1).unique().tolist()
year_list.sort()
print('Years: {}'.format( year_list ))
df_national
# Out:
# Num of rows: 1397
# Num of columns: 58
# Years: ['2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022']
#      period_begin  period_end  period_duration region_type  region_type_id  \
# 0      2021-05-01  2021-05-31               30    national              11
# 1      2012-07-01  2012-07-31               30    national              11
# 2      2016-12-01  2016-12-31               30    national              11
# 3      2013-07-01  2013-07-31               30    national              11
# 4      2020-06-01  2020-06-30               30    national              11
# ...           ...         ...              ...         ...             ...
# 1392   2019-08-01  2019-08-31               30    national              11
# 1393   2021-02-01  2021-02-28               30    national              11
# 1394   2021-01-01  2021-01-31               30    national              11
# 1395   2013-06-01  2013-06-30               30    national              11
# 1396   2020-07-01  2020-07-31               30    national              11
#
#       table_id is_seasonally_adjusted     region      city state state_code  \
# 0         1400                      f   National  National  U.S.         US
# 1         1400                      f   National  National  U.S.         US
# 2         1400                      f   National  National  U.S.         US
# 3         1400                      f   National  National  U.S.         US
# 4         1400                      f   National  National  U.S.         US
# ...        ...                    ...        ...       ...   ...        ...
# 1392      1400                      t   National  National  U.S.         US
# 1393      1400                      t   National  National  U.S.         US
# 1394      1400                      t   National  National  U.S.         US
# 1395      1400                      t   National  National  U.S.         US
# 1396      1400                      t   National  National  U.S.         US
#
#                 property_type  property_type_id  median_sale_price  \
# 0                 Condo/Co-op                 3      301300.000000
# 1                 Condo/Co-op                 3      156724.000000
# 2                 Condo/Co-op                 3      224061.000000
# 3     Multi-Family (2-4 Unit)                 4      202779.000000
# 4                   Townhouse                13      281519.000000
# ...                       ...               ...                ...
# 1392              Condo/Co-op                 3      253450.248868
# 1393              Condo/Co-op                 3      284134.174945
# 1394          All Residential                -1      343587.556996
# 1395                Townhouse                13      194640.353543
# 1396                Townhouse                13      281656.727208
#
#       median_sale_price_mom  median_sale_price_yoy  median_list_price  \
# 0                 -0.001434               0.199340      310943.000000
# 1                 -0.037308               0.056702      160842.000000
# 2                 -0.042726               0.083361      226118.000000
# 3                  0.032906               0.166361      210828.000000
# 4                  0.035578               0.052216      292494.000000
# ...                     ...                    ...                ...
# 1392               0.018906               0.045311      270828.070374
# 1393              -0.000375               0.066501      304733.159383
# 1394               0.014564               0.145960      348961.153595
# 1395               0.035905               0.154180      197874.256178
# 1396               0.021590               0.070500      297109.304850
#
#       median_list_price_mom  median_list_price_yoy  median_ppsf  \
# 0                  0.000037               0.101064   264.000000
# 1                 -0.015689               0.019390   133.000000
# 2                 -0.044127               0.102278   189.000000
# 3                 -0.004812               0.188509    93.000000
# 4                  0.006157               0.078289   173.000000
# ...                     ...                    ...          ...
# 1392               0.019373               0.053014   214.430900
# 1393               0.015196               0.110109   246.020467
# 1394              -0.011566               0.118758   185.333206
# 1395               0.027022               0.145400   123.072594
# 1396               0.030687               0.108068   173.445311
#
#       median_ppsf_mom  median_ppsf_yoy  median_list_ppsf  \
# 0           -0.002196         0.254411        273.000000
# 1           -0.020710         0.045851        135.000000
# 2           -0.043132         0.075694        190.000000
# 3           -0.007394         0.127512         99.000000
# 4            0.045014         0.067908        181.000000
# ...               ...              ...               ...
# 1392         0.008084         0.045841        229.591479
# 1393        -0.003430         0.081607        266.433041
# 1394         0.016125         0.149425        190.365028
# 1395         0.024408         0.120744        125.041475
# 1396         0.014719         0.077771        183.885504
#
#       median_list_ppsf_mom  median_list_ppsf_yoy     homes_sold  \
# 0                -0.002539              0.130362   78553.000000
# 1                -0.023692              0.007986   52275.000000
# 2                -0.031668              0.098283   54289.000000
# 3                 0.002507              0.191431   10108.000000
# 4                 0.003020              0.077475   55586.000000
# ...                    ...                   ...            ...
# 1392              0.004277              0.034774   57174.359079
# 1393              0.005892              0.109650   69508.532375
# 1394             -0.006147              0.141972  623646.030741
# 1395              0.008231              0.107834   36549.453915
# 1396              0.026525              0.110442   58892.395356
#
#       homes_sold_mom  homes_sold_yoy  pending_sales  pending_sales_mom  \
# 0          -0.047537        1.119765   74952.000000          -0.006643
# 1          -0.085909        0.185500   36131.000000          -0.029908
# 2           0.011810       -0.009573   35360.000000          -0.155042
# 3           0.089694        0.236315    7724.000000           0.060080
# 4           0.372505       -0.038853   58874.000000           0.236137
# ...              ...             ...            ...                ...
# 1392       -0.017971       -0.058143   47530.227144          -0.047627
# 1393        0.000289        0.170706   62803.443829          -0.020043
# 1394        0.006434        0.208519  617662.258566           0.021825
# 1395        0.016315        0.185653   29643.594325           0.037021
# 1396        0.293333        0.179985   56028.058286           0.064558
#
#       pending_sales_yoy   new_listings  new_listings_mom  new_listings_yoy  \
# 0              0.719182   86096.000000         -0.053765          0.251672
# 1              0.282090   61937.000000         -0.048443          0.052594
# 2              0.058108   38786.000000         -0.249387         -0.030921
# 3              0.233784   15379.000000          0.057862          0.170383
# 4              0.143161   72518.000000          0.169892          0.070919
# ...                 ...            ...               ...               ...
# 1392          -0.088834   67836.065441          0.026783         -0.076370
# 1393           0.234736   73178.348386         -0.054147          0.034213
# 1394           0.318332  674696.563044         -0.045574          0.027978
# 1395           0.333317   45067.426805         -0.005062          0.188056
# 1396           0.224885   66297.409965          0.094938          0.145043
#
#           inventory  inventory_mom  inventory_yoy  months_of_supply  \
# 0     128559.000000      -0.014991      -0.258143          1.636583
# 1     247999.000000      -0.023823      -0.217345          4.744101
# 2     153453.000000      -0.109655      -0.120609          2.826609
# 3      54662.000000       0.033824      -0.060691          5.407789
# 4     116692.000000      -0.025694      -0.152704          2.099297
# ...             ...            ...            ...               ...
# 1392  174206.684528      -0.010807       0.038785          2.925128
# 1393  146368.560149      -0.069442      -0.136701          2.150299
# 1394  971299.859486      -0.054547      -0.338820          1.557877
# 1395  133407.604587      -0.012610      -0.095307          3.740719
# 1396  103062.587771      -0.059792      -0.187444          1.671156
#
#       months_of_supply_mom  months_of_supply_yoy  median_dom  median_dom_mom  \
# 0                 0.054074             -3.039752   25.000000            -4.0
# 1                 0.301729             -2.441865   73.000000            -2.0
# 2                -0.385620             -0.356899   51.000000             4.0
# 3                -0.292248             -1.709922   58.000000             2.0
# 4                -0.857984             -0.282083   37.000000             1.0
# ...                    ...                   ...         ...             ...
# 1392             -0.080073              0.193883   44.281049            -1.0
# 1393             -0.214999             -0.621574   36.377618             1.0
# 1394             -0.053337             -1.427719   24.157580            -2.0
# 1395             -0.036043             -1.207920   52.424188            -2.0
# 1396             -0.667865             -0.766238   38.431639            -7.0
#
#       median_dom_yoy  avg_sale_to_list  avg_sale_to_list_mom  \
# 0              -17.0          1.003115              0.005459
# 1              -28.0          0.965701              0.001409
# 2               -4.0          0.974272             -0.002575
# 3               -7.0          0.965301             -0.002252
# 4                4.0          0.990351              0.001053
# ...              ...               ...                   ...
# 1392             8.0          0.978998              0.000770
# 1393            -7.0          0.988687             -0.000348
# 1394           -22.0          1.001687              0.001989
# 1395           -25.0          0.981341              0.001053
# 1396            -1.0          0.989278              0.003662
#
#       avg_sale_to_list_yoy  sold_above_list  sold_above_list_mom  \
# 0                 0.025531         0.387587             0.042187
# 1                 0.011662         0.185658             0.005620
# 2                 0.002278         0.175381            -0.012982
# 3                 0.010951         0.267404            -0.014442
# 4                 0.000262         0.272010             0.006439
# ...                    ...              ...                  ...
# 1392             -0.002553         0.187666             0.000311
# 1393              0.007197         0.254822             0.008093
# 1394              0.016664         0.397412             0.011353
# 1395              0.011067         0.243214             0.000113
# 1396              0.003517         0.278805             0.038770
#
#       sold_above_list_yoy  price_drops  price_drops_mom  price_drops_yoy  \
# 0                0.205695     0.080205         0.002311        -0.028807
# 1                0.038733     0.061762        -0.000419        -0.019492
# 2                0.005919     0.066626        -0.064348        -0.010251
# 3                0.025173     0.056769         0.007539        -0.002524
# 4               -0.003565     0.108728         0.005704        -0.026907
# ...                   ...          ...              ...              ...
# 1392            -0.027597     0.117818        -0.004730         0.000957
# 1393             0.065834     0.103493        -0.004516        -0.015799
# 1394             0.170390     0.092742        -0.002480        -0.038222
# 1395             0.055357     0.056283        -0.001440        -0.005885
# 1396             0.034105     0.092318        -0.008508        -0.032081
#
#       off_market_in_two_weeks  off_market_in_two_weeks_mom  \
# 0                    0.498326                     0.010493
# 1                    0.284747                    -0.001828
# 2                    0.282451                    -0.034445
# 3                    0.291058                    -0.019936
# 4                    0.473103                     0.052687
# ...                       ...                          ...
# 1392                 0.352348                     0.002460
# 1393                 0.396412                     0.009126
# 1394                 0.492143                    -0.018089
# 1395                 0.380256                     0.005887
# 1396                 0.474949                     0.016514
#
#       off_market_in_two_weeks_yoy parent_metro_region  \
# 0                        0.115599                None
# 1                        0.067277                None
# 2                        0.027202                None
# 3                        0.020028                None
# 4                        0.061865                None
# ...                           ...                 ...
# 1392                    -0.039103                None
# 1393                     0.040792                None
# 1394                     0.098657                None
# 1395                     0.055374                None
# 1396                     0.088210                None
#
#      parent_metro_region_metro_code         last_updated
# 0                              None  2022-08-14 14:47:34
# 1                              None  2022-08-14 14:47:34
# 2                              None  2022-08-14 14:47:34
# 3                              None  2022-08-14 14:47:34
# 4                              None  2022-08-14 14:47:34
# ...                             ...                  ...
# 1392                           None  2022-08-16 00:00:00
# 1393                           None  2022-08-16 00:00:00
# 1394                           None  2022-08-16 00:00:00
# 1395                           None  2022-08-16 00:00:00
# 1396                           None  2022-08-16 00:00:00
#
# [1397 rows x 58 columns]

# %% [markdown]
# ##### <font color="orange">Enriched Query</font> 🌟

# %%
url = "https://us-housing-market-data.p.rapidapi.com/getNationalEnriched"

headers = {
	"X-RapidAPI-Key": rapid_api_key,
	"X-RapidAPI-Host": "us-housing-market-data.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers)
df_national_e = pd.DataFrame.from_dict(response.json(), orient='index')
print('Num of rows: {}'.format(len(df_national_e)))
print('Num of columns: {}'.format(len(df_national_e.columns)))
df_national_e.tail()
# Out:
# Num of rows: 254
# Num of columns: 69
#       fred.date  fred.total_population  fred.inflation_rate  \
# 249  2022-05-01            331893745.0             4.697859
# 250  2022-06-01            331893745.0             4.697859
# 251  2022-06-01            331893745.0             4.697859
# 252  2022-07-01            331893745.0             4.697859
# 253  2022-07-01            331893745.0             4.697859
#
#      fred.consumer_price_index  fred.interest_rate  \
# 249                   1.102352                0.25
# 250                   1.373608                0.25
# 251                   1.373608                0.25
# 252                   1.373608                0.25
# 253                   1.373608                0.25
#
#      fred.household_debt_to_gdp  fred.working_age_population  \
# 249                   80.004218                  207356962.3
# 250                   80.004218                  207486228.4
# 251                   80.004218                  207486228.4
# 252                   80.004218                  207494240.0
# 253                   80.004218                  207494240.0
#
#      fred.total_unfilled_job_vacancies  fred.employment_rate  \
# 249                         11303000.0             71.376155
# 250                         10698000.0             71.242452
# 251                         10698000.0             71.242452
# 252                         10698000.0             71.301078
# 253                         10698000.0             71.301078
#
#      fred.unemployment_rate  fred.long_term_gov_bond_yield_10_yr_rate  \
# 249                3.619301                                      2.90
# 250                3.619301                                      3.14
# 251                3.619301                                      3.14
# 252                3.619301                                      2.90
# 253                3.619301                                      2.90
#
#     redfin.period_begin redfin.period_end  redfin.period_duration  \
# 249          2022-05-01        2022-05-31                      30
# 250          2022-06-01        2022-06-30                      30
# 251          2022-06-01        2022-06-30                      30
# 252          2022-07-01        2022-07-31                      30
# 253          2022-07-01        2022-07-31                      30
#
#     redfin.region_type  redfin.region_type_id  redfin.table_id  \
# 249           national                     11             1400
# 250           national                     11             1400
# 251           national                     11             1400
# 252           national                     11             1400
# 253           national                     11             1400
#
#     redfin.is_seasonally_adjusted redfin.region redfin.city redfin.state  \
# 249                             f      National    National         U.S.
# 250                             t      National    National         U.S.
# 251                             f      National    National         U.S.
# 252                             f      National    National         U.S.
# 253                             t      National    National         U.S.
#
#     redfin.state_code redfin.property_type  redfin.property_type_id  \
# 249                US      All Residential                       -1
# 250                US      All Residential                       -1
# 251                US      All Residential                       -1
# 252                US      All Residential                       -1
# 253                US      All Residential                       -1
#
#      redfin.median_sale_price  redfin.median_sale_price_mom  \
# 249             430279.000000                      0.014482
# 250             409175.683445                     -0.005756
# 251             427032.000000                     -0.007548
# 252             412739.000000                     -0.033470
# 253             407581.194422                     -0.003897
#
#      redfin.median_sale_price_yoy  redfin.median_list_price  \
# 249                      0.148871             436230.000000
# 250                      0.105047             421259.882509
# 251                      0.107599             431146.000000
# 252                      0.076507             421684.000000
# 253                      0.081770             422270.872787
#
#      redfin.median_list_price_mom  redfin.median_list_price_yoy  \
# 249                      0.004076                      0.150667
# 250                      0.005073                      0.132965
# 251                     -0.011654                      0.134120
# 252                     -0.021947                      0.121120
# 253                      0.002400                      0.122709
#
#      redfin.median_ppsf  redfin.median_ppsf_mom  redfin.median_ppsf_yoy  \
# 249          237.000000                0.003048                0.167976
# 250          225.571619               -0.007112                0.119057
# 251          233.000000               -0.015285                0.128376
# 252          227.000000               -0.027410                0.097113
# 253          224.594095               -0.004334                0.097307
#
#      redfin.median_list_ppsf  redfin.median_list_ppsf_mom  \
# 249               234.000000                     0.000036
# 250               230.105752                     0.001663
# 251               231.000000                    -0.012235
# 252               229.000000                    -0.007013
# 253               230.801784                     0.003025
#
#      redfin.median_list_ppsf_yoy  redfin.homes_sold  redfin.homes_sold_mom  \
# 249                     0.148037      598037.000000               0.068691
# 250                     0.132670      522431.766752              -0.037245
# 251                     0.131910      620753.000000               0.037985
# 252                     0.122274      526945.000000              -0.151120
# 253                     0.124880      501114.548252              -0.040804
#
#      redfin.homes_sold_yoy  redfin.pending_sales  redfin.pending_sales_mom  \
# 249              -0.059576         605036.000000                  0.064770
# 250              -0.142791         495044.424217                 -0.021025
# 251              -0.155054         579661.000000                 -0.041939
# 252              -0.232854         547322.000000                 -0.055789
# 253              -0.193340         492698.200222                 -0.004739
#
#      redfin.pending_sales_yoy  redfin.new_listings  redfin.new_listings_mom  \
# 249                 -0.092131        762052.000000                 0.061112
# 250                 -0.137105        628858.555607                 0.001885
# 251                 -0.153437        803415.000000                 0.054278
# 252                 -0.154453        670766.000000                -0.165107
# 253                 -0.132912        626852.368034                -0.003190
#
#      redfin.new_listings_yoy  redfin.inventory  redfin.inventory_mom  \
# 249                 0.014448      8.945260e+05              0.138379
# 250                -0.014528      9.573217e+05              0.131645
# 251                -0.018117      1.067635e+06              0.193520
# 252                -0.166867      1.132745e+06              0.060986
# 253                -0.134652      9.885315e+05              0.032601
#
#      redfin.inventory_yoy  redfin.months_of_supply  \
# 249              0.104516                 1.495771
# 250              0.229824                 1.766516
# 251              0.208695                 1.719902
# 252              0.152806                 2.149647
# 253              0.183467                 1.858384
#
#      redfin.months_of_supply_mom  redfin.months_of_supply_yoy  \
# 249                     0.091566                     0.222218
# 250                     0.120939                     0.484744
# 251                     0.224131                     0.517594
# 252                     0.429744                     0.719143
# 253                     0.091868                     0.528500
#
#      redfin.median_dom  redfin.median_dom_mom  redfin.median_dom_yoy  \
# 249          17.000000                   -1.0                    1.0
# 250          24.073589                    1.0                    3.0
# 251          18.000000                    1.0                    3.0
# 252          21.000000                    3.0                    6.0
# 253          26.124405                    2.0                    6.0
#
#      redfin.avg_sale_to_list  redfin.avg_sale_to_list_mom  \
# 249                 1.030975                    -0.000418
# 250                 1.014005                    -0.006656
# 251                 1.022614                    -0.008362
# 252                 1.010228                    -0.012385
# 253                 1.006263                    -0.007742
#
#      redfin.avg_sale_to_list_yoy  redfin.sold_above_list  \
# 249                     0.009278                0.591556
# 250                    -0.003256                0.487826
# 251                    -0.002714                0.553703
# 252                    -0.012427                0.473373
# 253                    -0.011951                0.428298
#
#      redfin.sold_above_list_mom  redfin.sold_above_list_yoy  \
# 249                    0.004003                    0.057327
# 250                   -0.030244                   -0.008061
# 251                   -0.037852                   -0.009614
# 252                   -0.080330                   -0.082164
# 253                   -0.059528                   -0.072843
#
#      redfin.price_drops  redfin.price_drops_mom  redfin.price_drops_yoy  \
# 249            0.112783                0.034045                0.041955
# 250            0.130727                0.008413                0.047069
# 251            0.168510                0.055727                0.077979
# 252            0.209252                0.040741                0.096869
# 253            0.137691                0.006965                0.051550
#
#      redfin.off_market_in_two_weeks  redfin.off_market_in_two_weeks_mom  \
# 249                        0.553293                           -0.031837
# 250                        0.444172                           -0.036037
# 251                        0.460568                           -0.092725
# 252                        0.387740                           -0.072827
# 253                        0.411303                           -0.032869
#
#      redfin.off_market_in_two_weeks_yoy redfin.parent_metro_region  \
# 249                           -0.056050                       None
# 250                           -0.108216                       None
# 251                           -0.112371                       None
# 252                           -0.137117                       None
# 253                           -0.140901                       None
#
#     redfin.parent_metro_region_metro_code  redfin.last_updated
# 249                                  None  2022-08-14 14:47:34
# 250                                  None  2022-08-16 00:00:00
# 251                                  None  2022-08-14 14:47:34
# 252                                  None  2022-08-14 14:47:34
# 253                                  None  2022-08-16 00:00:00

# %% [markdown]
# #### <font color="purple">2. Metro Region</font> 🏘

# %% [markdown]
# ##### <font color="orange">Search Valid Metro Ids</font> 🔍

# %%
url = "https://us-housing-market-data.p.rapidapi.com/getRegionId"

querystring = {"region_type":"metro"}

headers = {
	"X-RapidAPI-Key": rapid_api_key,
	"X-RapidAPI-Host": "us-housing-market-data.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)
df_metro_ids = pd.DataFrame.from_dict(response.json(), orient='index')
print('Num of rows: {}'.format(len(df_metro_ids)))
df_metro_ids.head()
# Out:
# Num of rows: 795
#   region_id                       region   type
# 1     15680    California, MD metro area  metro
# 2     16300  Cedar Rapids, IA metro area  metro
# 3     44140   Springfield, MA metro area  metro
# 4     40420      Rockford, IL metro area  metro
# 5     19340     Davenport, IA metro area  metro

# %%
metro_id_search_str = 'Tampa'
df_metro_id_filter = df_metro_ids.loc[df_metro_ids['region'].str.contains(metro_id_search_str)]
metro_region_id = df_metro_id_filter['region_id'].iloc[0]
print('Region ID for {0} is {1}'.format(metro_id_search_str, metro_region_id))
# Out:
# Region ID for Tampa is 45300

# %% [markdown]
# ##### <font color="orange">Standard Query</font> ✨

# %%
url = "https://us-housing-market-data.p.rapidapi.com/getMetro"

querystring = {"metro_id":metro_region_id}

headers = {
	"X-RapidAPI-Key": rapid_api_key,
	"X-RapidAPI-Host": "us-housing-market-data.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)
df_metro = pd.DataFrame.from_dict(response.json(), orient='index')
print('Num of rows: {}'.format(len(df_metro)))
print('Num of columns: {}'.format(len(df_metro.columns)))
print('Last updated: {}'.format(df_metro['last_updated'].unique().tolist()[0]))
print('Lastest period: {}'.format(df_metro['period_end'].max()))
df_metro.head()
# Out:
# Num of rows: 1143
# Num of columns: 58
# Last updated: 2022-08-14 14:44:22
# Lastest period: 2022-07-31
#   period_begin  period_end  period_duration region_type  region_type_id  \
# 0   2012-07-01  2012-07-31               30       metro              -2
# 1   2022-04-01  2022-04-30               30       metro              -2
# 2   2020-09-01  2020-09-30               30       metro              -2
# 3   2018-02-01  2018-02-28               30       metro              -2
# 4   2014-06-01  2014-06-30               30       metro              -2
#
#    table_id is_seasonally_adjusted                region  city state  \
# 0     45300                      f  Tampa, FL metro area  None  None
# 1     45300                      f  Tampa, FL metro area  None  None
# 2     45300                      f  Tampa, FL metro area  None  None
# 3     45300                      f  Tampa, FL metro area  None  None
# 4     45300                      f  Tampa, FL metro area  None  None
#
#   state_code              property_type  property_type_id  median_sale_price  \
# 0         FL            All Residential                -1           120000.0
# 1         FL  Single Family Residential                 6           400000.0
# 2         FL    Multi-Family (2-4 Unit)                 4           235000.0
# 3         FL    Multi-Family (2-4 Unit)                 4           200000.0
# 4         FL                  Townhouse                13           137750.0
#
#    median_sale_price_mom  median_sale_price_yoy  median_list_price  \
# 0              -0.016756               0.071429           129900.0
# 1               0.038961               0.290323           415000.0
# 2              -0.160714               0.270270           279900.0
# 3               0.052632               0.324503           209950.0
# 4              -0.015368               0.007313           150175.0
#
#    median_list_price_mom  median_list_price_yoy  median_ppsf  median_ppsf_mom  \
# 0               0.000000               0.083403    75.024201        -0.017117
# 1               0.040100               0.261398   230.985915         0.045757
# 2              -0.031488               0.332857   132.874016        -0.019239
# 3              -0.045682               0.235727    97.520661        -0.053283
# 4               0.042882               0.080784    91.625295         0.031278
#
#    median_ppsf_yoy  median_list_ppsf  median_list_ppsf_mom  \
# 0         0.055028         81.194172              0.000903
# 1         0.318652        239.822652              0.041961
# 2         0.195443        166.606061              0.029037
# 3         0.086593        115.770674             -0.007445
# 4         0.094421         95.485411              0.003433
#
#    median_list_ppsf_yoy  homes_sold  homes_sold_mom  homes_sold_yoy  \
# 0              0.061337      3969.0       -0.075041        0.113949
# 1              0.302498      4520.0       -0.090543       -0.114940
# 2              0.289631        67.0        0.175439        0.155172
# 3              0.189256        49.0        0.289474        0.065217
# 4              0.091602       328.0        0.015480       -0.012048
#
#    pending_sales  pending_sales_mom  pending_sales_yoy  new_listings  \
# 0         1914.0          -0.087268           0.324567        5004.0
# 1         4480.0          -0.065693          -0.088134        5416.0
# 2           53.0           0.039216           0.232558          75.0
# 3           50.0          -0.107143           0.282051          77.0
# 4          245.0          -0.209677           0.276042         396.0
#
#    new_listings_mom  new_listings_yoy  inventory  inventory_mom  \
# 0          0.086645          0.211622    23340.0       0.007859
# 1          0.018620         -0.010053     3923.0       0.241456
# 2         -0.050633          0.470588      143.0       0.091603
# 3         -0.144444          0.013158      193.0       0.048913
# 4          0.076087          0.058824     1094.0      -0.044541
#
#    inventory_yoy  months_of_supply  months_of_supply_mom  \
# 0      -0.064454               5.9                   0.5
# 1       0.034001               0.9                   0.3
# 2      -0.077419               2.1                  -0.2
# 3       0.206250               3.9                  -0.9
# 4      -0.215208               3.3                  -0.2
#
#    months_of_supply_yoy  median_dom  median_dom_mom  median_dom_yoy  \
# 0                  -1.1       111.0             0.0           -20.0
# 1                   0.2         7.0             0.0            -3.0
# 2                  -0.6        42.0            13.0            -2.0
# 3                   0.4        25.0             0.0             0.0
# 4                  -0.9        55.0           -21.0           -37.0
#
#    avg_sale_to_list  avg_sale_to_list_mom  avg_sale_to_list_yoy  \
# 0          0.955037              0.000087              0.015108
# 1          1.019629              0.004638              0.019975
# 2          0.946287             -0.015999              0.021042
# 3          0.934621             -0.014865             -0.014263
# 4          0.970033             -0.000276             -0.004180
#
#    sold_above_list  sold_above_list_mom  sold_above_list_yoy  price_drops  \
# 0         0.165281             0.010538             0.021020          NaN
# 1         0.546903             0.046299             0.159200     0.251338
# 2         0.164179            -0.028803             0.043489     0.146853
# 3         0.142857             0.090226            -0.052795     0.207254
# 4         0.097561            -0.091294            -0.122319     0.191042
#
#    price_drops_mom  price_drops_yoy  off_market_in_two_weeks  \
# 0              NaN              NaN                 0.091954
# 1         0.017161         0.041006                 0.757589
# 2        -0.028719        -0.085405                 0.547170
# 3        -0.048181         0.013504                 0.460000
# 4        -0.240399              NaN                 0.236735
#
#    off_market_in_two_weeks_mom  off_market_in_two_weeks_yoy  \
# 0                     0.008978                     0.013753
# 1                    -0.007166                     0.046618
# 2                     0.037366                     0.128565
# 3                    -0.147143                    -0.232308
# 4                    -0.011652                     0.116943
#
#   parent_metro_region  parent_metro_region_metro_code         last_updated
# 0           Tampa, FL                           45300  2022-08-14 14:44:22
# 1           Tampa, FL                           45300  2022-08-14 14:44:22
# 2           Tampa, FL                           45300  2022-08-14 14:44:22
# 3           Tampa, FL                           45300  2022-08-14 14:44:22
# 4           Tampa, FL                           45300  2022-08-14 14:44:22

# %% [markdown]
# #### <font color="purple">3. State Region</font> 🏘
# Locate valid state abbreviation codes by visiting the BLS website - [USPS State Abbreviations and FIPS Codes](https://www.bls.gov/respondents/mwr/electronic-data-interchange/appendix-d-usps-state-abbreviations-and-fips-codes.htm)

# %% [markdown]
# ##### <font color="orange">Standard Query</font> ✨

# %%
state_code = "FL" # enter state code abbreviations
url = "https://us-housing-market-data.p.rapidapi.com/getState"

querystring = {"state_code": state_code} 

headers = {
	"X-RapidAPI-Key": rapid_api_key,
	"X-RapidAPI-Host": "us-housing-market-data.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)
df_state = pd.DataFrame.from_dict(response.json(), orient='index')
print('Num of rows: {}'.format(len(df_state)))
print('Num of columns: {}'.format(len(df_state.columns)))
print('Last updated: {}'.format(df_state['last_updated'].unique().tolist()[0]))
print('Lastest period: {}'.format(df_state['period_end'].max()))
df_state.head()
# Out:
# Num of rows: 635
# Num of columns: 58
# Last updated: 2022-08-14 14:44:22
# Lastest period: 2022-07-31
#   period_begin  period_end  period_duration region_type  region_type_id  \
# 0   2017-09-01  2017-09-30               30       state               4
# 1   2022-02-01  2022-02-28               30       state               4
# 2   2012-05-01  2012-05-31               30       state               4
# 3   2016-12-01  2016-12-31               30       state               4
# 4   2015-04-01  2015-04-30               30       state               4
#
#    table_id is_seasonally_adjusted   region  city    state state_code  \
# 0        19                      f  Florida  None  Florida         FL
# 1        19                      f  Florida  None  Florida         FL
# 2        19                      f  Florida  None  Florida         FL
# 3        19                      f  Florida  None  Florida         FL
# 4        19                      f  Florida  None  Florida         FL
#
#              property_type  property_type_id  median_sale_price  \
# 0              Condo/Co-op                 3             165100
# 1              Condo/Co-op                 3             290200
# 2  Multi-Family (2-4 Unit)                 4             103400
# 3          All Residential                -1             220100
# 4                Townhouse                13             165800
#
#    median_sale_price_mom  median_sale_price_yoy  median_list_price  \
# 0              -0.016695               0.096782           267700.0
# 1               0.017399               0.270803           434900.0
# 2              -0.081055               0.186150           146600.0
# 3               0.033389               0.097260           241500.0
# 4               0.025619               0.094292           224200.0
#
#    median_list_price_mom  median_list_price_yoy  median_ppsf  median_ppsf_mom  \
# 0              -0.011764               0.023962        154.0        -0.005228
# 1               0.039059               0.239578        264.0         0.037503
# 2              -0.042796               0.085994         47.0        -0.068863
# 3              -0.016191               0.073513        138.0         0.015847
# 4               0.009109               0.127729        112.0         0.006506
#
#    median_ppsf_yoy  median_list_ppsf  median_list_ppsf_mom  \
# 0         0.082397             170.0             -0.006014
# 1         0.358375             284.0              0.035903
# 2         0.016161              93.0             -0.044466
# 3         0.086929             150.0             -0.005893
# 4         0.080177             137.0             -0.000640
#
#    median_list_ppsf_yoy  homes_sold  homes_sold_mom  homes_sold_yoy  \
# 0              0.035499        5349       -0.245131       -0.175936
# 1              0.271819        8302        0.072610       -0.050114
# 2              0.062069         260       -0.061372       -0.029851
# 3              0.067962       31155        0.121773       -0.024394
# 4              0.129007        2523       -0.021334        0.172943
#
#    pending_sales  pending_sales_mom  pending_sales_yoy  new_listings  \
# 0         2936.0          -0.389351          -0.250638        5667.0
# 1         8487.0           0.056912           0.114511       10443.0
# 2          119.0          -0.040323           0.133333         215.0
# 3        18880.0          -0.101637           0.014563       30444.0
# 4         2092.0           0.078907          -0.032825        3117.0
#
#    new_listings_mom  new_listings_yoy  inventory  inventory_mom  \
# 0         -0.367099         -0.344325    35097.0      -0.025354
# 1          0.018929         -0.008639    16520.0      -0.018244
# 2          0.053922          0.279762     1081.0      -0.005520
# 3         -0.163810         -0.005456   131465.0      -0.030887
# 4         -0.041218          0.264503     9628.0      -0.019951
#
#    inventory_yoy  months_of_supply  months_of_supply_mom  \
# 0      -0.077269               6.6                   1.5
# 1      -0.432497               2.0                  -0.2
# 2      -0.158100               4.2                   0.3
# 3      -0.013544               4.2                  -0.7
# 4       0.215196               3.8                   0.0
#
#    months_of_supply_yoy  median_dom  median_dom_mom  median_dom_yoy  \
# 0                   0.7        78.0            -2.0            -9.0
# 1                  -1.3        38.0            -3.0           -29.0
# 2                  -0.6        94.0            -9.0            -1.0
# 3                   0.0        65.0            -2.0            -4.0
# 4                   0.1        71.0             4.0            -7.0
#
#    avg_sale_to_list  avg_sale_to_list_mom  avg_sale_to_list_yoy  \
# 0          0.951943              0.000652              0.000739
# 1          0.987634              0.005339              0.026675
# 2          0.926874             -0.012114              0.006543
# 3          0.964886             -0.000746             -0.000091
# 4          0.963949              0.001975             -0.002744
#
#    sold_above_list  sold_above_list_mom  sold_above_list_yoy  price_drops  \
# 0         0.056833             0.001513            -0.017115     0.095592
# 1         0.274392             0.043255             0.197962     0.092857
# 2         0.188462            -0.017315            -0.005568          NaN
# 3         0.118633            -0.007677            -0.022064     0.154726
# 4         0.122870             0.004561            -0.037056     0.163274
#
#    price_drops_mom  price_drops_yoy  off_market_in_two_weeks  \
# 0        -0.051950        -0.050296                 0.214622
# 1        -0.011321        -0.051458                 0.501488
# 2              NaN              NaN                 0.107834
# 3        -0.025953         0.006455                 0.275378
# 4        -0.020053        -0.002446                 0.256197
#
#    off_market_in_two_weeks_mom  off_market_in_two_weeks_yoy  \
# 0                    -0.071319                    -0.052755
# 1                     0.048376                     0.138479
# 2                    -0.131951                     0.003730
# 3                    -0.012300                     0.042381
# 4                    -0.007494                     0.061328
#
#   parent_metro_region parent_metro_region_metro_code         last_updated
# 0        South Region                           None  2022-08-14 14:44:22
# 1        South Region                           None  2022-08-14 14:44:22
# 2        South Region                           None  2022-08-14 14:44:22
# 3        South Region                           None  2022-08-14 14:44:22
# 4        South Region                           None  2022-08-14 14:44:22

# %% [markdown]
# ##### <font color="orange">Enriched Query</font> 🌟

# %%
url = "https://us-housing-market-data.p.rapidapi.com/getStateEnriched"

querystring = {"state_code":state_code}

headers = {
	"X-RapidAPI-Key": rapid_api_key,
	"X-RapidAPI-Host": "us-housing-market-data.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)
df_state_e = pd.DataFrame.from_dict(response.json(), orient='index')
print('Num of rows: {}'.format(len(df_state_e)))
print('Num of columns: {}'.format(len(df_state_e.columns)))
df_state_e.tail()
# Out:
# Num of rows: 127
# Num of columns: 70
#       fred.date  fred.total_population  fred.median_household_income  \
# 122  2022-03-01             21781128.0                       57435.0
# 123  2022-04-01             21781128.0                       57435.0
# 124  2022-05-01             21781128.0                       57435.0
# 125  2022-06-01             21781128.0                       57435.0
# 126  2022-07-01             21781128.0                       57435.0
#
#      fred.median_list_price  fred.median_inventory  \
# 122                449950.0                36544.0
# 123                472990.0                39429.0
# 124                490768.0                49266.0
# 125                498500.0                60479.0
# 126                485000.0                76833.0
#
#      fred.median_days_on_market  fred.rental_vacancy_rate  \
# 122                        37.0                       6.5
# 123                        35.0                       6.5
# 124                        32.0                       6.5
# 125                        34.0                       6.5
# 126                        36.0                       6.5
#
#      fred.home_ownership_rate  fred.home_value_index  fred.unemployment_rate  \
# 122                      67.2                 366088                     3.2
# 123                      67.2                 376793                     3.0
# 124                      67.2                 387543                     2.9
# 125                      67.2                 396607                     2.8
# 126                      67.2                 402837                     2.7
#
#      fred.building_permits_housing_units   fred.gdp redfin.period_begin  \
# 122                              13267.0  1226297.5          2022-03-01
# 123                              13511.0  1226297.5          2022-04-01
# 124                              12635.0  1226297.5          2022-05-01
# 125                              12002.0  1226297.5          2022-06-01
# 126                               9985.0  1226297.5          2022-07-01
#
#     redfin.period_end  redfin.period_duration redfin.region_type  \
# 122        2022-03-31                      30              state
# 123        2022-04-30                      30              state
# 124        2022-05-31                      30              state
# 125        2022-06-30                      30              state
# 126        2022-07-31                      30              state
#
#      redfin.region_type_id  redfin.table_id redfin.is_seasonally_adjusted  \
# 122                      4               19                             f
# 123                      4               19                             f
# 124                      4               19                             f
# 125                      4               19                             f
# 126                      4               19                             f
#
#     redfin.region redfin.city redfin.state redfin.state_code  \
# 122       Florida        None      Florida                FL
# 123       Florida        None      Florida                FL
# 124       Florida        None      Florida                FL
# 125       Florida        None      Florida                FL
# 126       Florida        None      Florida                FL
#
#     redfin.property_type  redfin.property_type_id  redfin.median_sale_price  \
# 122      All Residential                       -1                    388500
# 123      All Residential                       -1                    400000
# 124      All Residential                       -1                    410100
# 125      All Residential                       -1                    410500
# 126      All Residential                       -1                    400000
#
#      redfin.median_sale_price_mom  redfin.median_sale_price_yoy  \
# 122                      0.040755                      0.227207
# 123                      0.029864                      0.226987
# 124                      0.025220                      0.235568
# 125                      0.000970                      0.203545
# 126                     -0.025556                      0.172013
#
#      redfin.median_list_price  redfin.median_list_price_mom  \
# 122                  421300.0                      0.040109
# 123                  434500.0                      0.031373
# 124                  437900.0                      0.007925
# 125                  437800.0                     -0.000265
# 126                  429800.0                     -0.018276
#
#      redfin.median_list_price_yoy  redfin.median_ppsf  redfin.median_ppsf_mom  \
# 122                      0.246048               245.0                0.041102
# 123                      0.256163               251.0                0.030187
# 124                      0.246245               257.0                0.019121
# 125                      0.245859               255.0               -0.007644
# 126                      0.210917               250.0               -0.024454
#
#      redfin.median_ppsf_yoy  redfin.median_list_ppsf  \
# 122                0.278124                    261.0
# 123                0.275046                    267.0
# 124                0.278774                    267.0
# 125                0.234818                    266.0
# 126                0.197842                    263.0
#
#      redfin.median_list_ppsf_mom  redfin.median_list_ppsf_yoy  \
# 122                     0.025556                     0.273816
# 123                     0.025489                     0.276946
# 124                     0.001300                     0.252400
# 125                    -0.007345                     0.237070
# 126                    -0.010884                     0.217574
#
#      redfin.homes_sold  redfin.homes_sold_mom  redfin.homes_sold_yoy  \
# 122              45866               0.304457              -0.108342
# 123              42746              -0.068126              -0.164366
# 124              42895               0.003486              -0.086174
# 125              41279              -0.037673              -0.189065
# 126              33100              -0.198081              -0.265717
#
#      redfin.pending_sales  redfin.pending_sales_mom  redfin.pending_sales_yoy  \
# 122               42547.0                  0.184164                 -0.069136
# 123               39861.0                 -0.063218                 -0.057637
# 124               39409.0                 -0.011339                 -0.052805
# 125               36429.0                 -0.075617                 -0.138672
# 126               34197.0                 -0.061193                 -0.128850
#
#      redfin.new_listings  redfin.new_listings_mom  redfin.new_listings_yoy  \
# 122              50564.0                 0.183947                 0.001684
# 123              49186.0                -0.027445                -0.020336
# 124              52213.0                 0.061542                 0.071146
# 125              53916.0                 0.032616                 0.082281
# 126              46427.0                -0.138837                -0.055363
#
#      redfin.inventory  redfin.inventory_mom  redfin.inventory_yoy  \
# 122           57300.0              0.024239             -0.206635
# 123           61836.0              0.078880             -0.131212
# 124           70165.0              0.134695             -0.004582
# 125           82737.0              0.179178              0.173391
# 126           89877.0              0.086416              0.214160
#
#      redfin.months_of_supply  redfin.months_of_supply_mom  \
# 122                      1.2                         -0.4
# 123                      1.4                          0.2
# 124                      1.6                          0.2
# 125                      2.0                          0.4
# 126                      2.7                          0.7
#
#      redfin.months_of_supply_yoy  redfin.median_dom  redfin.median_dom_mom  \
# 122                         -0.2               24.0                   -4.0
# 123                          0.0               22.0                   -2.0
# 124                          0.1               22.0                    0.0
# 125                          0.6               23.0                    1.0
# 126                          1.1               24.0                    1.0
#
#      redfin.median_dom_yoy  redfin.avg_sale_to_list  \
# 122                  -15.0                 1.001569
# 123                  -10.0                 1.005024
# 124                   -8.0                 1.004126
# 125                   -5.0                 0.998515
# 126                   -3.0                 0.990480
#
#      redfin.avg_sale_to_list_mom  redfin.avg_sale_to_list_yoy  \
# 122                     0.006494                     0.020949
# 123                     0.003457                     0.018989
# 124                    -0.000897                     0.013423
# 125                    -0.005611                     0.003686
# 126                    -0.008035                    -0.004726
#
#      redfin.sold_above_list  redfin.sold_above_list_mom  \
# 122                0.407208                    0.055881
# 123                0.438684                    0.031499
# 124                0.433407                   -0.005277
# 125                0.390223                   -0.043185
# 126                0.321178                   -0.069073
#
#      redfin.sold_above_list_yoy  redfin.price_drops  redfin.price_drops_mom  \
# 122                    0.191613            0.145183                0.032356
# 123                    0.171374            0.162155                0.016957
# 124                    0.118196            0.220979                0.058824
# 125                    0.036530            0.296615                0.075635
# 126                   -0.044366            0.345138                0.048504
#
#      redfin.price_drops_yoy  redfin.off_market_in_two_weeks  \
# 122                0.004067                        0.552688
# 123                0.036844                        0.536246
# 124                0.095227                        0.504711
# 125                0.148652                        0.442105
# 126                0.178152                        0.365835
#
#      redfin.off_market_in_two_weeks_mom  redfin.off_market_in_two_weeks_yoy  \
# 122                           -0.000608                            0.071801
# 123                           -0.016431                            0.031280
# 124                           -0.031535                           -0.003551
# 125                           -0.062606                           -0.051901
# 126                           -0.076278                           -0.104908
#
#     redfin.parent_metro_region redfin.parent_metro_region_metro_code  \
# 122               South Region                                  None
# 123               South Region                                  None
# 124               South Region                                  None
# 125               South Region                                  None
# 126               South Region                                  None
#
#      redfin.last_updated
# 122  2022-08-14 14:44:22
# 123  2022-08-14 14:44:22
# 124  2022-08-14 14:44:22
# 125  2022-08-14 14:44:22
# 126  2022-08-14 14:44:22

# %% [markdown]
# #### <font color="purple">4. County Region</font> 🏘

# %% [markdown]
# ##### <font color="orange">Search Valid County Ids</font> 🔍

# %%
url = "https://us-housing-market-data.p.rapidapi.com/getRegionId"

querystring = {"region_type":"county"}

headers = {
	"X-RapidAPI-Key": rapid_api_key,
	"X-RapidAPI-Host": "us-housing-market-data.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)
df_county_ids = pd.DataFrame.from_dict(response.json(), orient='index')
print('Num of rows: {}'.format(len(df_county_ids)))
df_county_ids.head()
# Out:
# Num of rows: 2375
#     region_id                region    type
# 844      2170  Champaign County, OH  county
# 845       490     Putnam County, FL  county
# 846      1668     Monroe County, MO  county
# 847       741   Gallatin County, IL  county
# 848      2919    Wasatch County, UT  county

# %%
county_id_search_str = 'Hillsborough'
df_county_id_filter = df_county_ids.loc[df_county_ids['region'].str.contains(county_id_search_str)]
county_region_id = df_county_id_filter['region_id'].iloc[0]
print('Region ID for {0} is {1}'.format(county_id_search_str, county_region_id))
# Out:
# Region ID for Hillsborough is 464

# %% [markdown]
# ##### <font color="orange">Standard Query</font> ✨

# %%
url = "https://us-housing-market-data.p.rapidapi.com/getCounty"

querystring = {"county_id":county_region_id}

headers = {
	"X-RapidAPI-Key": rapid_api_key,
	"X-RapidAPI-Host": "us-housing-market-data.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)
df_county = pd.DataFrame.from_dict(response.json(), orient='index')
print('Num of rows: {}'.format(len(df_county)))
print('Num of columns: {}'.format(len(df_county.columns)))
print('Last updated: {}'.format(df_county['last_updated'].unique().tolist()[0]))
print('Lastest period: {}'.format(df_county['period_end'].max()))
df_county.head()
# Out:
# Num of rows: 635
# Num of columns: 58
# Last updated: 2022-08-14 14:44:22
# Lastest period: 2022-07-31
#   period_begin  period_end  period_duration region_type  region_type_id  \
# 0   2017-07-01  2017-07-31               30      county               5
# 1   2017-05-01  2017-05-31               30      county               5
# 2   2012-02-01  2012-02-29               30      county               5
# 3   2022-01-01  2022-01-31               30      county               5
# 4   2021-04-01  2021-04-30               30      county               5
#
#    table_id is_seasonally_adjusted                   region  city    state  \
# 0       464                      f  Hillsborough County, FL  None  Florida
# 1       464                      f  Hillsborough County, FL  None  Florida
# 2       464                      f  Hillsborough County, FL  None  Florida
# 3       464                      f  Hillsborough County, FL  None  Florida
# 4       464                      f  Hillsborough County, FL  None  Florida
#
#   state_code              property_type  property_type_id  median_sale_price  \
# 0         FL    Multi-Family (2-4 Unit)                 4           120250.0
# 1         FL                  Townhouse                13           157990.0
# 2         FL                  Townhouse                13           100902.5
# 3         FL  Single Family Residential                 6           375000.0
# 4         FL    Multi-Family (2-4 Unit)                 4           220500.0
#
#    median_sale_price_mom  median_sale_price_yoy  median_list_price  \
# 0               0.052516              -0.075000           229000.0
# 1              -0.042485               0.074762           235000.0
# 2               0.219439               0.261281           129900.0
# 3               0.013514               0.279392           369900.0
# 4              -0.081250               0.142487           320000.0
#
#    median_list_price_mom  median_list_price_yoy  median_ppsf  median_ppsf_mom  \
# 0              -0.000415               0.065116    73.125397         0.085819
# 1               0.026201               0.048896   103.225594        -0.020425
# 2              -0.000769               0.115500    68.774283         0.220373
# 3               0.046963               0.297895   204.910070         0.021005
# 4               0.032258               0.187869   148.533951         0.090414
#
#    median_ppsf_yoy  median_list_ppsf  median_list_ppsf_mom  \
# 0         0.074029        124.739040             -0.004349
# 1         0.063748        126.103833              0.009816
# 2         0.227811         76.123128             -0.015669
# 3         0.280889        208.117685              0.034216
# 4         0.201982        176.259795              0.036552
#
#    median_list_ppsf_yoy  homes_sold  homes_sold_mom  homes_sold_yoy  \
# 0              0.060875        16.0       -0.111111        0.066667
# 1              0.072670       275.0        0.238739        0.145833
# 2              0.078984       134.0        0.264151        0.145299
# 3              0.283275      1437.0       -0.291071       -0.012371
# 4              0.200532        24.0       -0.111111        1.181818
#
#    pending_sales  pending_sales_mom  pending_sales_yoy  new_listings  \
# 0           16.0           0.142857           0.333333          21.0
# 1          256.0           0.080169           0.312821         312.0
# 2           48.0          -0.020408           0.043478         153.0
# 3         1602.0           0.079515          -0.067520        1629.0
# 4           18.0          -0.250000           1.250000          31.0
#
#    new_listings_mom  new_listings_yoy  inventory  inventory_mom  \
# 0          0.615385         -0.086957       43.0      -0.044444
# 1          0.164179          0.339056      479.0       0.016985
# 2         -0.072727         -0.120690      835.0      -0.001196
# 3          0.153683         -0.088416     1186.0      -0.122781
# 4          0.631579          1.214286       41.0       0.205882
#
#    inventory_yoy  months_of_supply  months_of_supply_mom  \
# 0      -0.022727               2.7                   0.2
# 1      -0.125912               1.7                  -0.4
# 2      -0.262367               6.2                  -1.7
# 3      -0.344027               0.8                   0.1
# 4      -0.127660               1.7                   0.4
#
#    months_of_supply_yoy  median_dom  median_dom_mom  median_dom_yoy  \
# 0                  -0.2        23.0           -14.0           -24.0
# 1                  -0.6        20.0            -5.0           -29.0
# 2                  -3.5       117.0           -27.0            -3.0
# 3                  -0.4        12.0             2.0            -3.0
# 4                  -2.6         7.0            -8.0           -15.0
#
#    avg_sale_to_list  avg_sale_to_list_mom  avg_sale_to_list_yoy  \
# 0          0.932443              0.003325              0.040149
# 1          0.981810              0.001660              0.003552
# 2          0.971567              0.009990              0.022018
# 3          0.999790             -0.003901              0.009381
# 4          0.981678              0.016020              0.017840
#
#    sold_above_list  sold_above_list_mom  sold_above_list_yoy  price_drops  \
# 0         0.125000             0.013889             0.125000     0.325581
# 1         0.185455             0.041310             0.047955     0.237996
# 2         0.164179             0.013236             0.061615          NaN
# 3         0.412665            -0.003714             0.152184     0.197302
# 4         0.291667             0.069444             0.018939     0.121951
#
#    price_drops_mom  price_drops_yoy  off_market_in_two_weeks  \
# 0        -0.007752         0.121036                 0.625000
# 1         0.008696         0.062813                 0.429688
# 2              NaN              NaN                 0.083333
# 3        -0.026071        -0.065972                 0.662297
# 4        -0.113343        -0.154645                 0.666667
#
#    off_market_in_two_weeks_mom  off_market_in_two_weeks_yoy  \
# 0                    -0.017857                     0.375000
# 1                    -0.106177                     0.050200
# 2                    -0.018707                    -0.003623
# 3                     0.029548                     0.054032
# 4                     0.291667                     0.041667
#
#   parent_metro_region  parent_metro_region_metro_code         last_updated
# 0           Tampa, FL                         45300.0  2022-08-14 14:44:22
# 1           Tampa, FL                         45300.0  2022-08-14 14:44:22
# 2           Tampa, FL                         45300.0  2022-08-14 14:44:22
# 3           Tampa, FL                         45300.0  2022-08-14 14:44:22
# 4           Tampa, FL                         45300.0  2022-08-14 14:44:22

# %% [markdown]
# ##### <font color="orange">Enriched Query</font> 🌟

# %%
url = "https://us-housing-market-data.p.rapidapi.com/getCountyEnriched"

querystring = {"county_id":county_region_id}

headers = {
	"X-RapidAPI-Key": rapid_api_key,
	"X-RapidAPI-Host": "us-housing-market-data.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)
df_county_e = pd.DataFrame.from_dict(response.json(), orient='index')
print('Num of rows: {}'.format(len(df_county_e)))
print('Num of columns: {}'.format(len(df_county_e.columns)))
df_county_e.tail()
# Out:
# Num of rows: 127
# Num of columns: 74
#       fred.date  fred.total_population  fred.median_household_income  \
# 122  2022-03-01              1478194.0                       65272.0
# 123  2022-04-01              1478194.0                       65272.0
# 124  2022-05-01              1478194.0                       65272.0
# 125  2022-06-01              1478194.0                       65272.0
# 126  2022-07-01              1478194.0                       65272.0
#
#      fred.median_list_price  fred.median_inventory  \
# 122                426900.0                 4799.0
# 123                440000.0                 5040.0
# 124                450000.0                 5623.0
# 125                462500.0                 6182.0
# 126                459500.0                 6833.0
#
#      fred.median_days_on_market  fred.market_hotness_rank  \
# 122                        31.0                     225.0
# 123                        28.0                     308.0
# 124                        26.0                     510.0
# 125                        28.0                     629.0
# 126                        29.0                     645.0
#
#      fred.count_of_crime_offenses  fred.poverty_rate  fred.unemployment_rate  \
# 122                       10606.0               14.0                     2.5
# 123                       10606.0               14.0                     2.3
# 124                       10606.0               14.0                     2.3
# 125                       10606.0               14.0                     2.8
# 126                       10606.0               14.0                     2.7
#
#      fred.civilian_labor_force  fred.building_permits_housing_units  \
# 122                     789073                              11281.0
# 123                     791276                              11281.0
# 124                     795747                              11281.0
# 125                     800604                              11281.0
# 126                     803151                              11281.0
#
#      fred.home_ownership_rate    fred.gdp          fred.county fred.state  \
# 122                 61.423444  96832749.0  Hillsborough County         FL
# 123                 61.423444  96832749.0  Hillsborough County         FL
# 124                 61.423444  96832749.0  Hillsborough County         FL
# 125                 61.423444  96832749.0  Hillsborough County         FL
# 126                 61.423444  96832749.0  Hillsborough County         FL
#
#     redfin.period_begin redfin.period_end  redfin.period_duration  \
# 122          2022-03-01        2022-03-31                      30
# 123          2022-04-01        2022-04-30                      30
# 124          2022-05-01        2022-05-31                      30
# 125          2022-06-01        2022-06-30                      30
# 126          2022-07-01        2022-07-31                      30
#
#     redfin.region_type  redfin.region_type_id  redfin.table_id  \
# 122             county                      5              464
# 123             county                      5              464
# 124             county                      5              464
# 125             county                      5              464
# 126             county                      5              464
#
#     redfin.is_seasonally_adjusted            redfin.region redfin.city  \
# 122                             f  Hillsborough County, FL        None
# 123                             f  Hillsborough County, FL        None
# 124                             f  Hillsborough County, FL        None
# 125                             f  Hillsborough County, FL        None
# 126                             f  Hillsborough County, FL        None
#
#     redfin.state redfin.state_code redfin.property_type  \
# 122      Florida                FL      All Residential
# 123      Florida                FL      All Residential
# 124      Florida                FL      All Residential
# 125      Florida                FL      All Residential
# 126      Florida                FL      All Residential
#
#      redfin.property_type_id  redfin.median_sale_price  \
# 122                       -1                  377990.0
# 123                       -1                  395000.0
# 124                       -1                  400000.0
# 125                       -1                  410000.0
# 126                       -1                  407582.5
#
#      redfin.median_sale_price_mom  redfin.median_sale_price_yoy  \
# 122                      0.027147                      0.303414
# 123                      0.045001                      0.316667
# 124                      0.012658                      0.298512
# 125                      0.025000                      0.281250
# 126                     -0.005896                      0.254100
#
#      redfin.median_list_price  redfin.median_list_price_mom  \
# 122                  386662.5                     -0.006009
# 123                  409000.0                      0.057770
# 124                  416442.5                      0.018197
# 125                  419900.0                      0.008302
# 126                  415000.0                     -0.011669
#
#      redfin.median_list_price_yoy  redfin.median_ppsf  redfin.median_ppsf_mom  \
# 122                      0.247298          213.980029                0.038829
# 123                      0.278125          224.311043                0.048280
# 124                      0.281362          229.088233                0.021297
# 125                      0.261340          230.164671                0.004699
# 126                      0.213805          230.427925                0.001144
#
#      redfin.median_ppsf_yoy  redfin.median_list_ppsf  \
# 122                0.310047               221.591067
# 123                0.346934               230.621397
# 124                0.331441               230.514988
# 125                0.295917               230.516529
# 126                0.266297               231.650673
#
#      redfin.median_list_ppsf_mom  redfin.median_list_ppsf_yoy  \
# 122                     0.032403                     0.303137
# 123                     0.040752                     0.308417
# 124                    -0.000461                     0.271711
# 125                     0.000007                     0.267841
# 126                     0.004920                     0.250914
#
#      redfin.homes_sold  redfin.homes_sold_mom  redfin.homes_sold_yoy  \
# 122             2492.0               0.210884              -0.096774
# 123             2275.0              -0.087079              -0.181949
# 124             2392.0               0.051429              -0.091531
# 125             2435.0               0.017977              -0.190223
# 126             2098.0              -0.138398              -0.224112
#
#      redfin.pending_sales  redfin.pending_sales_mom  redfin.pending_sales_yoy  \
# 122                2481.0                  0.220965                 -0.106911
# 123                2258.0                 -0.089883                 -0.165250
# 124                2575.0                  0.140390                 -0.046649
# 125                2315.0                 -0.100971                 -0.152015
# 126                2240.0                 -0.032397                 -0.169139
#
#      redfin.new_listings  redfin.new_listings_mom  redfin.new_listings_yoy  \
# 122               2674.0                 0.197492                -0.065035
# 123               2827.0                 0.057218                -0.050067
# 124               3133.0                 0.108242                 0.083708
# 125               3482.0                 0.111395                 0.136423
# 126               2991.0                -0.141011                -0.053181
#
#      redfin.inventory  redfin.inventory_mom  redfin.inventory_yoy  \
# 122            1584.0              0.027904             -0.116564
# 123            2068.0              0.305556              0.104111
# 124            2533.0              0.224855              0.326873
# 125            3596.0              0.419660              0.708314
# 126            4208.0              0.170189              0.720360
#
#      redfin.months_of_supply  redfin.months_of_supply_mom  \
# 122                      0.6                         -0.1
# 123                      0.9                          0.3
# 124                      1.1                          0.2
# 125                      1.5                          0.4
# 126                      2.0                          0.5
#
#      redfin.months_of_supply_yoy  redfin.median_dom  redfin.median_dom_mom  \
# 122                          0.0                7.0                   -1.0
# 123                          0.2                6.0                   -1.0
# 124                          0.4                7.0                    1.0
# 125                          0.8                8.0                    1.0
# 126                          1.1               10.0                    2.0
#
#      redfin.median_dom_yoy  redfin.avg_sale_to_list  \
# 122                   -4.0                 1.015571
# 123                   -2.0                 1.023400
# 124                    1.0                 1.019241
# 125                    2.0                 1.010353
# 126                    3.0                 0.999577
#
#      redfin.avg_sale_to_list_mom  redfin.avg_sale_to_list_yoy  \
# 122                     0.006466                     0.023341
# 123                     0.007829                     0.024290
# 124                    -0.004159                     0.014135
# 125                    -0.008888                     0.000411
# 126                    -0.010776                    -0.009105
#
#      redfin.sold_above_list  redfin.sold_above_list_mom  \
# 122                0.518860                    0.057733
# 123                0.576703                    0.057843
# 124                0.545569                   -0.031135
# 125                0.512115                   -0.033454
# 126                0.404194                   -0.107921
#
#      redfin.sold_above_list_yoy  redfin.price_drops  redfin.price_drops_mom  \
# 122                    0.212228            0.212121                0.036910
# 123                    0.194467            0.224371                0.012250
# 124                    0.112223            0.299645                0.075273
# 125                    0.019598            0.404616                0.104972
# 126                   -0.075465            0.521150                0.116534
#
#      redfin.price_drops_yoy  redfin.off_market_in_two_weeks  \
# 122               -0.026027                        0.773478
# 123               -0.004673                        0.765722
# 124                0.064967                        0.731262
# 125                0.125756                        0.632397
# 126                0.229654                        0.488839
#
#      redfin.off_market_in_two_weeks_mom  redfin.off_market_in_two_weeks_yoy  \
# 122                            0.013636                            0.039497
# 123                           -0.007757                            0.004169
# 124                           -0.034460                           -0.052151
# 125                           -0.098865                           -0.129141
# 126                           -0.143558                           -0.237422
#
#     redfin.parent_metro_region  redfin.parent_metro_region_metro_code  \
# 122                  Tampa, FL                                45300.0
# 123                  Tampa, FL                                45300.0
# 124                  Tampa, FL                                45300.0
# 125                  Tampa, FL                                45300.0
# 126                  Tampa, FL                                45300.0
#
#      redfin.last_updated
# 122  2022-08-14 14:44:22
# 123  2022-08-14 14:44:22
# 124  2022-08-14 14:44:22
# 125  2022-08-14 14:44:22
# 126  2022-08-14 14:44:22

# %% [markdown]
# #### <font color="purple">5. Zipcode Region</font> 🏘

# %% [markdown]
# ##### <font color="orange">Standard Query</font> ✨

# %%
zipcode = "33610" # enter state code abbreviations
url = "https://us-housing-market-data.p.rapidapi.com/getZipcode"

querystring = {"zipcode":zipcode}

headers = {
	"X-RapidAPI-Key": rapid_api_key,
	"X-RapidAPI-Host": "us-housing-market-data.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)
df_zipcode = pd.DataFrame.from_dict(response.json(), orient='index')
print('Num of rows: {}'.format(len(df_zipcode)))
print('Num of columns: {}'.format(len(df_zipcode.columns)))
print('Last updated: {}'.format(df_zipcode['last_updated'].unique().tolist()[0]))
print('Lastest period: {}'.format(df_zipcode['period_end'].max()))
df_zipcode.head()
# Out:
# Num of rows: 462
# Num of columns: 59
# Last updated: 2022-08-14 14:44:22
# Lastest period: 2022-07-31
#   period_begin  period_end  period_duration region_type  region_type_id  \
# 0   2018-06-01  2018-08-31               90    zip code               2
# 1   2012-05-01  2012-07-31               90    zip code               2
# 2   2020-09-01  2020-11-30               90    zip code               2
# 3   2017-08-01  2017-10-31               90    zip code               2
# 4   2014-04-01  2014-06-30               90    zip code               2
#
#    table_id is_seasonally_adjusted           region  city    state state_code  \
# 0     14276                      f  Zip Code: 33610  None  Florida         FL
# 1     14276                      f  Zip Code: 33610  None  Florida         FL
# 2     14276                      f  Zip Code: 33610  None  Florida         FL
# 3     14276                      f  Zip Code: 33610  None  Florida         FL
# 4     14276                      f  Zip Code: 33610  None  Florida         FL
#
#                property_type  property_type_id  median_sale_price  \
# 0            All Residential                -1           149428.5
# 1                  Townhouse                13            98000.0
# 2  Single Family Residential                 6           205000.0
# 3                  Townhouse                13           138950.0
# 4    Multi-Family (2-4 Unit)                 4            90000.0
#
#    median_sale_price_mom  median_sale_price_yoy  median_list_price  \
# 0              -0.026207               0.149450           149450.0
# 1               0.000000               0.171898           109000.0
# 2               0.000000               0.281250           215000.0
# 3              -0.007500              -0.007500           144900.0
# 4               0.000000                    NaN            24700.0
#
#    median_list_price_mom  median_list_price_yoy  median_ppsf  median_ppsf_mom  \
# 0               0.010309               0.086909   113.358204         0.017391
# 1               0.045313               0.191908    54.884742         0.010101
# 2               0.003669               0.265450   148.677686        -0.016294
# 3               0.003463               0.097727    85.123276         0.050052
# 4              -0.173913                    NaN    46.524742        -0.017811
#
#    median_ppsf_yoy  median_list_ppsf  median_list_ppsf_mom  \
# 0         0.283887        113.494829              0.079076
# 1         0.148717         60.332404              0.019279
# 2         0.183206        157.704240              0.022946
# 3         0.005265         84.630728              0.012469
# 4              NaN         11.160253             -0.040368
#
#    median_list_ppsf_yoy  homes_sold  homes_sold_mom  homes_sold_yoy  \
# 0              0.160753       132.0        0.015385       -0.102041
# 1              0.135868        25.0       -0.107143        1.500000
# 2              0.146940       125.0       -0.119718        0.086957
# 3              0.057172        24.0       -0.111111        0.846154
# 4                   NaN         4.0        0.333333             NaN
#
#    pending_sales  pending_sales_mom  pending_sales_yoy  new_listings  \
# 0           45.0           0.216216              0.125         187.0
# 1            NaN                NaN                NaN          52.0
# 2           32.0          -0.179487             -0.200         131.0
# 3            3.0           0.000000             -0.500          21.0
# 4            NaN                NaN                NaN           2.0
#
#    new_listings_mom  new_listings_yoy  inventory  inventory_mom  \
# 0          0.246667          0.230263      122.0       0.270833
# 1          0.529412          1.166667       67.0       0.313725
# 2          0.082645         -0.176101       81.0       0.080000
# 3          0.050000          0.235294       11.0       0.571429
# 4          1.000000               NaN        3.0       0.000000
#
#    inventory_yoy months_of_supply months_of_supply_mom months_of_supply_yoy  \
# 0       0.140187             None                 None                 None
# 1       0.367347             None                 None                 None
# 2      -0.325000             None                 None                 None
# 3       0.222222             None                 None                 None
# 4            NaN             None                 None                 None
#
#    median_dom  median_dom_mom  median_dom_yoy  avg_sale_to_list  \
# 0        26.0            -1.5             1.0          0.969534
# 1       183.0            12.0            88.0          0.955787
# 2        18.0           -18.0            -1.0          0.984465
# 3        12.0             3.0           -25.0          0.981628
# 4       352.0             0.0             NaN          0.932546
#
#    avg_sale_to_list_mom  avg_sale_to_list_yoy  sold_above_list  \
# 0             -0.002257              0.009052          0.19697
# 1              0.010509              0.015904          0.20000
# 2              0.005700              0.008112          0.28800
# 3              0.012549             -0.003822          0.12500
# 4             -0.039676                   NaN          0.00000
#
#    sold_above_list_mom  sold_above_list_yoy price_drops price_drops_mom  \
# 0             0.012354             0.013296        None            None
# 1             0.092857             0.200000        None            None
# 2            -0.000732             0.035826        None            None
# 3            -0.023148            -0.182692        None            None
# 4             0.000000                  NaN        None            None
#
#   price_drops_yoy  off_market_in_two_weeks  off_market_in_two_weeks_mom  \
# 0            None                 0.577778                     0.010210
# 1            None                      NaN                          NaN
# 2            None                 0.468750                    -0.044071
# 3            None                 0.333333                    -0.333333
# 4            None                      NaN                          NaN
#
#    off_market_in_two_weeks_yoy parent_metro_region  \
# 0                     0.177778           Tampa, FL
# 1                          NaN           Tampa, FL
# 2                    -0.056250           Tampa, FL
# 3                    -0.500000           Tampa, FL
# 4                          NaN           Tampa, FL
#
#    parent_metro_region_metro_code         last_updated  zipcode
# 0                           45300  2022-08-14 14:44:22    33610
# 1                           45300  2022-08-14 14:44:22    33610
# 2                           45300  2022-08-14 14:44:22    33610
# 3                           45300  2022-08-14 14:44:22    33610
# 4                           45300  2022-08-14 14:44:22    33610

# %% [markdown]
# ##### <font color="orange">Enriched Query</font> 🌟

# %%
url = "https://us-housing-market-data.p.rapidapi.com/getZipcodeEnriched"

querystring = {"zipcode":zipcode}

headers = {
	"X-RapidAPI-Key": rapid_api_key,
	"X-RapidAPI-Host": "us-housing-market-data.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)
df_zipcode_e = pd.DataFrame.from_dict(response.json(), orient='index')
print('Num of rows: {}'.format(len(df_zipcode_e)))
print('Num of columns: {}'.format(len(df_zipcode_e.columns)))
df_zipcode_e.tail()
# Out:
# Num of rows: 72
# Num of columns: 80
#     census.year  census.state  census.zipcode  census.total_population  \
# 67         2020            12           33610                   285357
# 68         2020            12           33610                   285357
# 69         2020            12           33610                   285357
# 70         2020            12           33610                   285357
# 71         2020            12           33610                   285357
#
#     census.total_population_sex_male  census.total_population_sex_female  \
# 67                            137542                              147815
# 68                            137542                              147815
# 69                            137542                              147815
# 70                            137542                              147815
# 71                            137542                              147815
#
#     census.total_population_race_white  census.total_population_race_black  \
# 67                              148892                              108758
# 68                              148892                              108758
# 69                              148892                              108758
# 70                              148892                              108758
# 71                              148892                              108758
#
#     census.total_population_race_aian  census.total_population_race_asian  \
# 67                                669                                4759
# 68                                669                                4759
# 69                                669                                4759
# 70                                669                                4759
# 71                                669                                4759
#
#     census.total_population_race_api  census.total_population_poverty  \
# 67                               106                            56992
# 68                               106                            56992
# 69                               106                            56992
# 70                               106                            56992
# 71                               106                            56992
#
#     census.median_household_income  census.median_rent_all_bds  \
# 67                         59708.5                      1048.0
# 68                         59708.5                      1048.0
# 69                         59708.5                      1048.0
# 70                         59708.5                      1048.0
# 71                         59708.5                      1048.0
#
#     census.median_rent_0_beds  census.median_rent_1_beds  \
# 67                      901.5                      820.5
# 68                      901.5                      820.5
# 69                      901.5                      820.5
# 70                      901.5                      820.5
# 71                      901.5                      820.5
#
#     census.median_rent_2_beds  census.median_rent_3_beds  \
# 67                      990.0                     1178.0
# 68                      990.0                     1178.0
# 69                      990.0                     1178.0
# 70                      990.0                     1178.0
# 71                      990.0                     1178.0
#
#     census.median_rent_4_beds census.median_rent_5+_beds redfin.period_begin  \
# 67                     1433.0                       None          2020-06-01
# 68                     1433.0                       None          2020-03-01
# 69                     1433.0                       None          2020-12-01
# 70                     1433.0                       None          2020-02-01
# 71                     1433.0                       None          2020-01-01
#
#    redfin.period_end  redfin.period_duration redfin.region_type  \
# 67        2020-08-31                      90           zip code
# 68        2020-05-31                      90           zip code
# 69        2021-02-28                      90           zip code
# 70        2020-04-30                      90           zip code
# 71        2020-03-31                      90           zip code
#
#     redfin.region_type_id  redfin.table_id redfin.is_seasonally_adjusted  \
# 67                      2            14276                             f
# 68                      2            14276                             f
# 69                      2            14276                             f
# 70                      2            14276                             f
# 71                      2            14276                             f
#
#       redfin.region redfin.city redfin.state redfin.state_code  \
# 67  Zip Code: 33610        None      Florida                FL
# 68  Zip Code: 33610        None      Florida                FL
# 69  Zip Code: 33610        None      Florida                FL
# 70  Zip Code: 33610        None      Florida                FL
# 71  Zip Code: 33610        None      Florida                FL
#
#          redfin.property_type  redfin.property_type_id  \
# 67  Single Family Residential                        6
# 68  Single Family Residential                        6
# 69  Single Family Residential                        6
# 70  Single Family Residential                        6
# 71  Single Family Residential                        6
#
#     redfin.median_sale_price  redfin.median_sale_price_mom  \
# 67                  200000.0                      0.025641
# 68                  188995.0                      0.049972
# 69                  189500.0                     -0.052500
# 70                  180000.0                      0.063830
# 71                  169200.0                     -0.004120
#
#     redfin.median_sale_price_yoy  redfin.median_list_price  \
# 67                      0.286174                  214984.0
# 68                      0.181219                  188450.0
# 69                      0.115362                  213000.0
# 70                      0.125704                  174900.0
# 71                      0.158904                  179000.0
#
#     redfin.median_list_price_mom  redfin.median_list_price_yoy  \
# 67                      0.023977                      0.243041
# 68                      0.077473                      0.177816
# 69                      0.000000                      0.217839
# 70                     -0.022905                      0.093809
# 71                      0.023442                      0.119450
#
#     redfin.median_ppsf  redfin.median_ppsf_mom  redfin.median_ppsf_yoy  \
# 67          144.545992                0.039278                0.183283
# 68          137.049180                0.000000                0.117761
# 69          156.503378                0.026662                0.210146
# 70          137.049180                0.058667                0.151098
# 71          129.454427                0.000993                0.035635
#
#     redfin.median_list_ppsf  redfin.median_list_ppsf_mom  \
# 67               151.225059                     0.011336
# 68               143.048510                     0.049897
# 69               169.878654                     0.035351
# 70               136.250000                    -0.010949
# 71               137.758297                     0.000000
#
#     redfin.median_list_ppsf_yoy  redfin.homes_sold  redfin.homes_sold_mom  \
# 67                     0.194646              141.0               0.137097
# 68                     0.120579              117.0              -0.048780
# 69                     0.233165              116.0              -0.008547
# 70                     0.068004              123.0               0.008197
# 71                     0.118253              122.0               0.025210
#
#     redfin.homes_sold_yoy  redfin.pending_sales  redfin.pending_sales_mom  \
# 67               0.014388                  43.0                 -0.156863
# 68              -0.158273                  44.0                  0.375000
# 69              -0.025210                  47.0                  0.146341
# 70              -0.061069                  32.0                  0.066667
# 71               0.008264                  30.0                 -0.142857
#
#     redfin.pending_sales_yoy  redfin.new_listings  redfin.new_listings_mom  \
# 67                 -0.044444                144.0                -0.152941
# 68                  0.189189                146.0                 0.149606
# 69                  0.342857                141.0                 0.044444
# 70                 -0.238095                127.0                -0.248521
# 71                 -0.268293                169.0                 0.149660
#
#     redfin.new_listings_yoy  redfin.inventory  redfin.inventory_mom  \
# 67                -0.127273              81.0             -0.205882
# 68                -0.087500             115.0              0.026786
# 69                -0.040816              65.0             -0.029851
# 70                -0.175325             112.0             -0.157895
# 71                 0.090323             133.0              0.047244
#
#     redfin.inventory_yoy redfin.months_of_supply redfin.months_of_supply_mom  \
# 67             -0.256881                    None                        None
# 68              0.017699                    None                        None
# 69             -0.488189                    None                        None
# 70              0.087379                    None                        None
# 71              0.209091                    None                        None
#
#    redfin.months_of_supply_yoy  redfin.median_dom  redfin.median_dom_mom  \
# 67                        None               52.0                   -4.5
# 68                        None               57.0                    6.0
# 69                        None               23.0                   -3.0
# 70                        None               51.0                    4.0
# 71                        None               47.0                    6.0
#
#     redfin.median_dom_yoy  redfin.avg_sale_to_list  \
# 67                   27.0                 0.974224
# 68                   22.0                 0.975526
# 69                  -18.0                 0.982061
# 70                   13.0                 0.964704
# 71                   11.5                 0.952523
#
#     redfin.avg_sale_to_list_mom  redfin.avg_sale_to_list_yoy  \
# 67                    -0.003532                     0.004063
# 68                     0.010822                     0.009069
# 69                    -0.001772                     0.031667
# 70                     0.012181                    -0.002921
# 71                     0.002129                    -0.008045
#
#     redfin.sold_above_list  redfin.sold_above_list_mom  \
# 67                0.283688                   -0.022764
# 68                0.290598                    0.071086
# 69                0.267241                   -0.006263
# 70                0.219512                    0.055578
# 71                0.163934                    0.012674
#
#     redfin.sold_above_list_yoy redfin.price_drops redfin.price_drops_mom  \
# 67                    0.039084               None                   None
# 68                    0.002829               None                   None
# 69                    0.115981               None                   None
# 70                   -0.001862               None                   None
# 71                   -0.009619               None                   None
#
#    redfin.price_drops_yoy  redfin.off_market_in_two_weeks  \
# 67                   None                        0.395349
# 68                   None                        0.454545
# 69                   None                        0.680851
# 70                   None                        0.218750
# 71                   None                        0.466667
#
#     redfin.off_market_in_two_weeks_mom  redfin.off_market_in_two_weeks_yoy  \
# 67                           -0.134063                           -0.249096
# 68                            0.235795                            0.022113
# 69                            0.266217                            0.195137
# 70                           -0.247917                           -0.233631
# 71                           -0.019048                           -0.143089
#
#    redfin.parent_metro_region  redfin.parent_metro_region_metro_code  \
# 67                  Tampa, FL                                  45300
# 68                  Tampa, FL                                  45300
# 69                  Tampa, FL                                  45300
# 70                  Tampa, FL                                  45300
# 71                  Tampa, FL                                  45300
#
#     redfin.last_updated  redfin.zipcode  redfin.year
# 67  2022-08-14 14:44:22           33610         2020
# 68  2022-08-14 14:44:22           33610         2020
# 69  2022-08-14 14:44:22           33610         2020
# 70  2022-08-14 14:44:22           33610         2020
# 71  2022-08-14 14:44:22           33610         2020

# %% [markdown]
# #### <font color="purple">6. Neighborhood Region</font> 🏘

# %% [markdown]
# ##### <font color="orange">Search Valid Neighborhood Ids</font> 🔍

# %%
url = "https://us-housing-market-data.p.rapidapi.com/getRegionId"

querystring = {"region_type":"neighborhood"}

headers = {
	"X-RapidAPI-Key": rapid_api_key,
	"X-RapidAPI-Host": "us-housing-market-data.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)
df_neighborhood_ids = pd.DataFrame.from_dict(response.json(), orient='index')
print('Num of rows: {}'.format(len(df_neighborhood_ids)))
df_neighborhood_ids.head()
# Out:
# Num of rows: 38459
#       region_id                                        region          type
# 43555    119928  Anaheim, CA - The Highlands at Anaheim Hills  neighborhood
# 43556    352009                      Memphis, TN - River Oaks  neighborhood
# 43557    764968     Wilmington, NC - Millbrook-Masonboro Loop  neighborhood
# 43558    760210                          Mobile, AL - Melrose  neighborhood
# 43559    549879                   Warren, RI - Downton Warren  neighborhood

# %%
neighborhood_id_search_str = 'Ybor'
df_neighborhood_id_filter = df_neighborhood_ids.loc[
    df_neighborhood_ids['region'].str.contains(neighborhood_id_search_str)]
df_neighborhood_id_filter
# Out:
#       region_id                                   region          type
# 48318     76738           Tampa, FL - Historic Ybor City  neighborhood
# 49307    557460  Tampa, FL - Ybor City Historic District  neighborhood
# 51448     70147           Tampa, FL - East Ybor Historic  neighborhood
# 54845    557451                   Tampa, FL - North Ybor  neighborhood
# 58616    134740                   Tampa, FL - V. M. Ybor  neighborhood
# 67621    764519                 Tampa, FL - Ybor Heights  neighborhood

# %% [markdown]
# ##### <font color="orange">Standard Query</font> ✨

# %%
neighborhood_id = "76738" # enter neighborhood id here
url = "https://us-housing-market-data.p.rapidapi.com/getNeighborhood"

querystring = {"neighborhood_id":neighborhood_id}

headers = {
	"X-RapidAPI-Key": rapid_api_key,
	"X-RapidAPI-Host": "us-housing-market-data.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)
df_neighborhood = pd.DataFrame.from_dict(response.json(), orient='index')
print('Num of rows: {}'.format(len(df_neighborhood)))
print('Num of columns: {}'.format(len(df_neighborhood.columns)))
print('Last updated: {}'.format(df_neighborhood['last_updated'].unique().tolist()[0]))
print('Lastest period: {}'.format(df_neighborhood['period_end'].max()))
df_neighborhood.head()
# Out:
# Num of rows: 419
# Num of columns: 58
# Last updated: 2022-08-14 14:44:22
# Lastest period: 2022-07-31
#   period_begin  period_end  period_duration   region_type  region_type_id  \
# 0   2019-12-01  2020-02-29               90  neighborhood               1
# 1   2012-01-01  2012-03-31               90  neighborhood               1
# 2   2018-04-01  2018-06-30               90  neighborhood               1
# 3   2017-01-01  2017-03-31               90  neighborhood               1
# 4   2013-11-01  2014-01-31               90  neighborhood               1
#
#    table_id is_seasonally_adjusted                          region   city  \
# 0     76738                      f  Tampa, FL - Historic Ybor City  Tampa
# 1     76738                      f  Tampa, FL - Historic Ybor City  Tampa
# 2     76738                      f  Tampa, FL - Historic Ybor City  Tampa
# 3     76738                      f  Tampa, FL - Historic Ybor City  Tampa
# 4     76738                      f  Tampa, FL - Historic Ybor City  Tampa
#
#      state state_code    property_type  property_type_id  median_sale_price  \
# 0  Florida         FL  All Residential                -1           133500.0
# 1  Florida         FL        Townhouse                13           135000.0
# 2  Florida         FL        Townhouse                13           232000.0
# 3  Florida         FL  All Residential                -1           199000.0
# 4  Florida         FL  All Residential                -1            94500.0
#
#    median_sale_price_mom  median_sale_price_yoy  median_list_price  \
# 0              -0.200599              -0.157729           170000.0
# 1               0.125000                    NaN           140000.0
# 2               0.000000               0.007819           259500.0
# 3               0.421429               0.009384           144450.0
# 4              -0.091346               0.400000            84950.0
#
#    median_list_price_mom  median_list_price_yoy  median_ppsf  median_ppsf_mom  \
# 0              -0.291371               0.203540   186.011905        -0.024707
# 1               0.000000                    NaN    79.646018        -0.138496
# 2               0.000000               0.140910   209.009009         0.000000
# 3               0.032523               0.179665   165.477533         0.147311
# 4              -0.052954               0.089103    98.039216        -0.017622
#
#    median_ppsf_yoy  median_list_ppsf  median_list_ppsf_mom  \
# 0         0.068029        188.988095             -0.084850
# 1              NaN         82.233608              0.000000
# 2         0.296055        209.274194              0.000000
# 3         0.102931        162.567976              0.028396
# 4         0.122735        104.166667              0.008517
#
#    median_list_ppsf_yoy  homes_sold  homes_sold_mom  homes_sold_yoy  \
# 0             -0.060998        17.0       -0.227273        0.416667
# 1                   NaN         1.0        0.000000             NaN
# 2              0.314975         1.0        0.000000       -0.500000
# 3              0.187011        12.0        0.333333        0.000000
# 4              0.205774        17.0       -0.055556        1.125000
#
#    pending_sales  pending_sales_mom  pending_sales_yoy  new_listings  \
# 0            7.0           1.333333           1.333333          13.0
# 1            1.0                NaN                NaN           2.0
# 2            NaN                NaN                NaN           3.0
# 3            1.0          -0.857143          -0.800000          16.0
# 4            4.0           0.000000           1.000000          18.0
#
#    new_listings_mom  new_listings_yoy  inventory  inventory_mom  \
# 0         -0.133333         -0.071429       14.0      -0.300000
# 1          0.000000               NaN        2.0      -0.333333
# 2          0.000000          0.500000        2.0       0.000000
# 3         -0.058824          0.142857        7.0       0.000000
# 4         -0.100000         -0.142857       20.0       0.052632
#
#    inventory_yoy months_of_supply months_of_supply_mom months_of_supply_yoy  \
# 0      -0.222222             None                 None                 None
# 1            NaN             None                 None                 None
# 2            NaN             None                 None                 None
# 3      -0.461538             None                 None                 None
# 4      -0.047619             None                 None                 None
#
#    median_dom  median_dom_mom  median_dom_yoy  avg_sale_to_list  \
# 0        94.0            18.5            33.5          0.971862
# 1        70.0           -33.0             NaN          0.964286
# 2         NaN             NaN             NaN          1.000000
# 3        19.0             0.0           -81.0          0.967014
# 4        58.0            -6.0           -59.0          0.966989
#
#    avg_sale_to_list_mom  avg_sale_to_list_yoy  sold_above_list  \
# 0             -0.000642              0.004418         0.058824
# 1             -0.136632                   NaN         0.000000
# 2              0.000000             -0.011004         0.000000
# 3              0.002683             -0.006535         0.083333
# 4             -0.000887             -0.005491         0.235294
#
#    sold_above_list_mom  sold_above_list_yoy price_drops price_drops_mom  \
# 0            -0.032086             0.058824        None            None
# 1            -1.000000                  NaN        None            None
# 2             0.000000            -0.500000        None            None
# 3             0.083333             0.000000        None            None
# 4             0.068627            -0.139706        None            None
#
#   price_drops_yoy  off_market_in_two_weeks  off_market_in_two_weeks_mom  \
# 0            None                 0.285714                    -0.380952
# 1            None                 0.000000                          NaN
# 2            None                      NaN                          NaN
# 3            None                 0.000000                    -0.714286
# 4            None                 0.000000                     0.000000
#
#    off_market_in_two_weeks_yoy parent_metro_region  \
# 0                    -0.047619           Tampa, FL
# 1                          NaN           Tampa, FL
# 2                          NaN           Tampa, FL
# 3                    -0.600000           Tampa, FL
# 4                     0.000000           Tampa, FL
#
#    parent_metro_region_metro_code         last_updated
# 0                           45300  2022-08-14 14:44:22
# 1                           45300  2022-08-14 14:44:22
# 2                           45300  2022-08-14 14:44:22
# 3                           45300  2022-08-14 14:44:22
# 4                           45300  2022-08-14 14:44:22

# %% [markdown]
# ### <font color="green">Section #2 - Loops</font> 🏙
# Get data for multiple regions

# %% [markdown]
# *coming soon*

# %% [markdown]
# ### <font color="green">Section #3 - Visualization</font> 📈
# Visualize housing and economic data trends over time

# %% [markdown]
# *coming soon*

# %% [markdown]
# # End Notebook
